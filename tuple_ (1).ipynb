# %%
#Tuples

# Tuples are used to store multiple items in a single variable.
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
# A tuple is a collection which is ordered and unchangeable.
# Tuples are written with round brackets.

# %%
thistuple = ("apple","banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple","banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple = ("apple",)
print(type(thistuple))

thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
thistuple= (23,3,54)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
thistuple = (23, "apple", 2.0)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
thistuple = tuple(("apple"))

# %%
var = input("enter a tuple")
print(type(eval(var)))
# Out:
# enter a tuple(1,2,3)
# <class 'tuple'>

# %%
thistuple = ("apple","banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple = ("apple","banana", "cherry")
print(thistuple[-2])
# Out:
# banana

# %%
thistuple = ("apple","banana","cherry")
print(thistuple[::2])
# Out:
# ('apple', 'cherry')

# %%
thistuple = ("apple","banana","cherry","orange","kiwi","mango")
print(thistuple[2::3])
# Out:
# ('cherry', 'mango')

# %%
thistuple = ("apple","banana","cherry")
if "apple" in thistuple:
 print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %%
x = ("apple","banana","cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
x = ("apple","banana","cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
#packing a tuple
fruits = ("apple","banana","cherry")
print(fruits)
# Out:
# ('apple', 'banana', 'cherry')

# %%
#Unpacking a tuple
fruits = ("apple","banana","cherry")

(green, yellow, red) = fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple","banana","cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple","banana","cherry")

green,yellow,_ = fruits
print(green)
print(yellow)
# Out:
# apple
# banana

# %%
# Asterisk
fruits = ("apple","banana","cherry","strawberry","raspberry")

(green,yellow, *red) = fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
thistuple = ("apple","banana","cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
tuple1 = ("a", "b", "c")
tuple2 = (1,2,3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
fruits = ("apple","banana","cherry")
mytuple = fruits * 2
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
thistuple = (1,2,3,4,5,1,2,3,4,2,3,4)
x = thistuple.count(2)
print(x)
# Out:
# 3

# %%
thistuple = (1,2,3,4,5,6,3,4,5)
x = thistuple.index(7)
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-276453149.py in <cell line: 0>()
#       1 thistuple = (1,2,3,4,5,6,3,4,5)
# ----> 2 x = thistuple.index(7)
#       3 print(x)
#
# ValueError: tuple.index(x): x not in tuple

# %%
# write program to convert a list into a tuple
# write a program to find the largest and smallest element in a tuple
# Write a program to slice a tuple and print every second elements
# write a program to store student records using tuples and search by roll number
